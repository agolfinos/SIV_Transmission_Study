# %% [markdown]
# ## Purpose
#
# Characterize the sequences in Nef RM9 epitope. Processes a folder hierarchy of FASTQ files and saves Nef RM9 sequences, counts and statistics files to a corresponding folder hierarchy. This script will generate a tsv file with nucleotide sequences and the number of times they are present in the data set.

# %% [markdown]
# ## Specify dataset arguments
#
# Specify variables that need to be changed depending on the dataset and machine configuration. After these parameters are specified, the rest of the notebook should be runnable automatically.

# %%
# path to FASTQ files to process
# expects R1 and R2 paired samples
FASTQ_FOLDER_PATH = 'Raw_FASTQs/'

# path to folder containing barcode counts, intermediate files, and statistics
OUTPUT_PATH = 'GW9_counts/'

# path to bbmap
BBMAP_PATH = 'bin/bbmap/'

# path to reference file for read orientation
REF_FASTA = 'ref/M33262.fasta'

# 20bp of upstream and downstream sequences flanking Gag GW9
UPSTREAM_FLANKING = 'TTGCAGCAGCCCAACAGAGG'
DOWNSTREAM_FLANKING = 'AATTGTGGGAAAGAGGGACA'

# %% [markdown]
# ## Functions
#
# Define functions that will be used in the workflow to count barcodes from FASTQ files.

# %%
# import logger

def print_status(status):
    '''print timestamped status update'''
    
    from datetime import datetime
    import logging
    
    log = logging.getLogger(__name__)
    
    print('--[' + datetime.now().strftime('%Y-%m-%d %H:%M:%S') + '] ' + status + '--')
    log.info(status)

def create_temp_file():
    '''create named temporary file
    return temporary file object [0] and path to temporary file [1]'''

    import pathlib
    import tempfile
    
    temp = tempfile.NamedTemporaryFile()    
    return [temp, temp.name]

def create_directory(dir_path):
    '''create directory at specified location if one does not already exist'''
    
    import os
    
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
        
    return dir_path

def copy_and_overwrite(from_path, to_path):
    '''duplicate folder and file hierarchy'''
    import os
    import shutil
     
    print_status('Copying files from ' + from_path + ' to ' + to_path)
    if os.path.exists(to_path):
        shutil.rmtree(to_path)
    shutil.copytree(from_path, to_path)
    
def find_files_in_path(search_path):
    '''get list of files matching files in search_path'''
    import glob
    
    f = glob.glob(search_path, recursive=True)
    
    return f

def derive_file_name(source_file, find_string, replace_string):
    '''create filename string '''
    
    f = source_file.replace(find_string, replace_string)
    
    return f

def run_command(cmd_list, stdout_file = None, stderr_file = None):
    '''run command with subprocess.call
    if stdout or stderr arguments are passed, save to specified file
    '''
    
    import subprocess
    
    print_status(' '.join(cmd_list)) # print status
    
    # if neither stdout or stderr specified
    if stdout_file is None and stderr_file is None:
        print(cmd_list)
        subprocess.call(cmd_list)
     
    # if only stdout is specified
    elif stdout_file is not None and stderr_file is None:
        with open(stdout_file, 'w') as so:
            subprocess.call(cmd_list, stdout = so)
     
    # if only stderr is specified
    elif stdout_file is None and stderr_file is not None:
        with open(stderr_file, 'w') as se:
            subprocess.call(cmd_list, stderr = se)
     
    # if both stdout and stderr are specified
    elif stdout_file is not None and stderr_file is not None:
        with open(stdout_file, 'w') as so:
            with open(stderr_file, 'w') as se:
                subprocess.call(cmd_list, stdout = so, stderr = se)
    
    else: pass
    
def split_path(source_file):
    '''get path to enclosing folder and basename for source_file'''
    
    import os
    
    source_file_path = os.path.dirname(source_file)
    source_file_basename = os.path.basename(source_file)
    
    return [source_file_path, source_file_basename]

def create_barcode_tsv(two_column_barcode_count_file, three_column_barcode_count_file, sample_name):
    '''add a column with sample_name to barcode count TSV output by kmercountexact'''
    
    import pandas as pd 
    
    # import file containing counts to pandas dataframe    
    df = pd.read_csv(two_column_barcode_count_file, sep='\t', names=['barcode_sequence', 'barcode_count'])
    
    # add column with sample name
    df.insert(0, 'sample_name', sample_name)
    
    # export CSV with sample names added
    df.to_csv(three_column_barcode_count_file, sep='\t', index=False)
    
def remove_file(source_file):
    '''remove file'''
    
    import os
    
    os.remove(source_file)

# %% [markdown]
# ## Workflow
#
# Count numbers of barcodes in FASTQ sequences by:
#
# 1. Create folders to store barcode counts, intermediate files, and tools statistics
# 1. Make dictionary of samples to process
# 1. Iterate over every sample to process and:
# 1. Quality trimming and merging R1 and R2 FASTQ sequences
# 1. Extracting reads that contain the barcode
# 1. Orient reads in same direction
# 1. Trim reads to contain only the barcode
# 1. Count number of times each barcode occurs
# 1. Create TSV file with barcode counts for each sequence

# %% [markdown]
# ### 1.
#
# Checks if the output folder designated by the user exists, and creates it if not. The function then generates the output folder structure based on the input folder structure.

# %%
## 1. Create folders to store barcode counts, intermediate files, and tools statistics ##

copy_and_overwrite(from_path = FASTQ_FOLDER_PATH, to_path = OUTPUT_PATH)
# Out:
# --[2019-09-30 16:16:42] Copying files from Raw_FASTQs/ to GW9_counts/--

# %% [markdown]
# ### 2.
#
# Creates a dictionary of sample names, where the key is the sample directory path and the value is the file name sans forward/reverse designator and file extension.

# %%
## 2. Make dictionary of samples to process ##

FASTQ_R1 = find_files_in_path(OUTPUT_PATH + '/**/*_R1_001.fastq.gz')

SAMPLES = {}

for i in FASTQ_R1:
    
    # get path to directory containing sample FASTQ
    SAMPLE_DIR = split_path(i)[0]
    
    # get sample name
    FASTQ_R1_BASENAME = split_path(i)[1]
    SAMPLE_NAME = derive_file_name(FASTQ_R1_BASENAME, '_R1_001.fastq.gz', '')
    
    SAMPLES[i] = (SAMPLE_DIR, SAMPLE_NAME)

# %% [markdown]
# ### 3.
#
# Iterates over every sample in the dictionary to create a stats file and...
#
# ### 4.
#
# Merges and quality trims the forward and reverse FASTQ reads using bbmerge.
#
# ### 5.
#
# - Extracts reads containing the user-defined upstream flanking sequence, allowing for a 1 bp mismatch.
# - From those reads, extracts reads containing the user-defined downstream flanking sequence, again allowing for a 1 bp mismatch.
#
# ### 6.
#
# - Maps reads to Zika virus reference using bbmap.
# - Using bbmap's splitsam utility, identifies plus and minus strands in the output sam file. Regenerates FASTQ files for plus and minus reads, and takes the reverse complement of the minus strands before concatenating the two files into a single FASTQ.
#
# ### 7.
#
# Using bbduk, removes the upstream and downstream flanking sequences, again allowing for a 1 bp mismatch. By orienting the reads in Step 6, the upstream sequence can be left-trimmed and the downstream sequence can be right-trimmed without needing to account for reverse complements.
#
# ### 8.
#
# Counts the number of times each 24mer barcode appears in each sample. By limiting to 24 bp, any PCR chimeras containing > 24 bp between flanking sequences are removed.
#
# ### 9.
#
# Outputs a TSV file with barcode counts for each sequence, and removes temporary files created in the above steps.

# %%
## 3. Iterate over every sample to process and: ##

for key,val in SAMPLES.items():
    
    # get sample path and sample name
    SAMPLE_PATH = val[0]
    SAMPLE_NAME = val[1]
    
    # create directory to hold statistics files
    STATS_PATH = create_directory(SAMPLE_PATH + '/stats')

    ## 4. Quality trimming and merging R1 and R2 FASTQ sequences ##
    
    # merge and quality trim
    run_command([BBMAP_PATH + 'bbmerge.sh',
                 'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '_R1_001.fastq.gz',
                 'in2=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '_R2_001.fastq.gz',
                 'out=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.merged.fastq.gz',
                 'qtrim=t',
                 'ow=t'],
                 stderr_file = STATS_PATH + '/' + SAMPLE_NAME + '.merging.stats.txt')
    
    ## 5. Extracting reads that contain the barcode ##
    
    # extract reads containing barcode
    # bbduk command to find reads containing upstream flanking sequence   
    run_command([BBMAP_PATH + 'bbduk.sh',
                  'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.merged.fastq.gz',
                  'outm=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_upstream_flank.fastq.gz',
                  'literal=' + UPSTREAM_FLANKING,
                  'k=20',
                  'hdist=1',
                  'ow=t'],
                  stderr_file = STATS_PATH + '/' + SAMPLE_NAME + '.containing_upstream_flank.stats.txt')
    
    # bbduk command to find reads containing downstream flanking sequence 
    # (among those that contain upstream flanking sequence)
    run_command([BBMAP_PATH + 'bbduk.sh',
                  'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_upstream_flank.fastq.gz',
                  'outm=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_barcode.fastq.gz',
                  'literal=' + DOWNSTREAM_FLANKING,
                  'k=20',
                  'hdist=1',
                  'ow=t'],
                  stderr_file=STATS_PATH + '/' + SAMPLE_NAME + '.containing_barcode.stats.txt')
    
    ## 6. Orient reads in same direction ##title
    
    # orient reads by mapping to reference
    # use SIV reference with accession M33262
    run_command([BBMAP_PATH + 'bbmap.sh',
                'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_barcode.fastq.gz',
                'outm=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.mapped.sam',
                'ref=' + REF_FASTA,
                'ow=t'],
                stderr_file=STATS_PATH + '/' + SAMPLE_NAME + '.mapping.stats.txt')
    
    # split mapped SAM file into plus, minus, and unmapped strand SAM temporary files
    PLUS_STRAND_SAM = create_temp_file()
    MINUS_STRAND_SAM = create_temp_file()
    UNMAPPED_STRAND_SAM = create_temp_file()
    
    run_command([BBMAP_PATH + 'splitsam.sh',
                SAMPLE_PATH + '/' + SAMPLE_NAME + '.mapped.sam',
                PLUS_STRAND_SAM[1] + '.sam',
                MINUS_STRAND_SAM[1] + '.sam',
                UNMAPPED_STRAND_SAM[1] + '.sam'])    
    
    # reformat plus and minus strand SAM files to FASTQ
    PLUS_STRAND_FASTQ = create_temp_file()
    MINUS_STRAND_FASTQ = create_temp_file()    

    run_command([BBMAP_PATH + 'reformat.sh',
                'in=' + PLUS_STRAND_SAM[1] + '.sam',
                'out=' + PLUS_STRAND_FASTQ[1] + '.fastq.gz'])
                 
    run_command([BBMAP_PATH + 'reformat.sh',
                'in=' + MINUS_STRAND_SAM[1] + '.sam',
                'out=' + MINUS_STRAND_FASTQ[1] + '.fastq.gz',
                'rcomp=t'])
    
    # concatenate oriented plus and minus strand FASTQ
    run_command(['cat',
                PLUS_STRAND_FASTQ[1] + '.fastq.gz',
                MINUS_STRAND_FASTQ[1] + '.fastq.gz'],
               stdout_file = SAMPLE_PATH + '/' + SAMPLE_NAME + '.oriented.fastq.gz')
    
    ## 7. Trim reads to contain only the barcode ##
    
    # remove upstream flanking sequence from oriented reads
    UPSTREAM_FLANK_REMOVED = create_temp_file()
    
    run_command([BBMAP_PATH + 'bbduk.sh',
               'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.oriented.fastq.gz',
               'out=' + UPSTREAM_FLANK_REMOVED[1] + '.fastq.gz',
               'literal=' + UPSTREAM_FLANKING,
               'ktrim=l',
               'rcomp=f',
               'k=20',
               'hdist=1',
               'ow=t'],
               stderr_file = STATS_PATH + '/' + SAMPLE_NAME + '.upstream.flank.removal.stats.txt')
    
    # remove downstream flanking sequence from oriented reads
    run_command([BBMAP_PATH + 'bbduk.sh',
               'in=' + UPSTREAM_FLANK_REMOVED[1] + '.fastq.gz',
               'out=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.barcodes.fastq.gz',
               'literal=' + DOWNSTREAM_FLANKING,
               'ktrim=r',
               'rcomp=f',
               'k=20',
               'hdist=1',
               'minlength=27',  
               'maxlength=27',
               'ow=t'],
               stderr_file = STATS_PATH + '/' + SAMPLE_NAME + '.downstream.flank.removal.stats.txt')
    
    
    ## 8. Count number of times each barcode occurs ##
    
    # count number of identical barcodes in each sample
    
    # create temporary count file
    BARCODE_COUNT_TEMP = create_temp_file()
    
    run_command([BBMAP_PATH + 'kmercountexact.sh',
          'in=' + SAMPLE_PATH + '/' + SAMPLE_NAME + '.barcodes.fastq.gz',
          'out=' + BARCODE_COUNT_TEMP[1] + '.txt',
          'fastadump=f',
          'k=27',
          'rcomp=f'])
#took last argument out of this, which was 'ow=t'. I couldn't find this in the documentation
    
    ## 9. Create TSV file with barcode counts for each sequence ##
    
    # create three column barcode count file with sample name
    create_barcode_tsv(BARCODE_COUNT_TEMP[1] + '.txt',
                       SAMPLE_PATH + '/' + SAMPLE_NAME + '.Gag_GW9_barcode_counts.txt',
                       SAMPLE_NAME)
    
    # remove temporary files
    PLUS_STRAND_SAM[0].close()
    PLUS_STRAND_FASTQ[0].close()
    MINUS_STRAND_SAM[0].close()
    MINUS_STRAND_FASTQ[0].close()
    UNMAPPED_STRAND_SAM[0].close()
    UPSTREAM_FLANK_REMOVED[0].close()
    BARCODE_COUNT_TEMP
    
    # remove intermediate files
    # copies of these already exist in 02-renamed_fastq/
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '_R1.fastq.gz')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '_R2.fastq.gz')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '.merged.fastq.gz')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_upstream_flank.fastq.gz')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '.containing_barcode.fastq.gz')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '.mapped.sam')
    #remove_file(SAMPLE_PATH + '/' + SAMPLE_NAME + '.oriented.fastq.gz')
# Out:
# --[2019-09-30 16:17:15] bin/bbmap/bbmerge.sh in=GW9_counts/966-53_S53_L001_R1_001.fastq.gz in2=GW9_counts/966-53_S53_L001_R2_001.fastq.gz out=GW9_counts/966-53_S53_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16
fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp0d2pso57.fastq.gz--
# --[2019-09-30 16:20:42] bin/bbmap/bbduk.sh in=GW9_counts/848-03_S3_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpetsp9enj.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:20:43] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpetsp9enj.fastq.gz out=GW9_counts/848-03_S3_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:20:43] bin/bbmap/kmercountexact.sh in=GW9_counts/848-03_S3_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpz_aahx37.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/848-03_S3_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpz_aahx37.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:20:43] bin/bbmap/bbmerge.sh in=GW9_counts/20063_S1_L001_R1_001.fastq.gz in2=GW9_counts/20063_S1_L001_R2_001.fastq.gz out=GW9_counts/20063_S1_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:20:51] bin/bbmap/bbduk.sh in=GW9_counts/20063_S1_L001.merged.fastq.gz outm=GW9_counts/20063_S1_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:20:52] bin/bbmap/bbduk.sh in=GW9_counts/20063_S1_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/20063_S1_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:20:53] bin/bbmap/bbmap.sh in=GW9_counts/20063_S1_L001.containing_barcode.fastq.gz outm=GW9_counts/20063_S1_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:20:58] bin/bbmap/splitsam.sh GW9_counts/20063_S1_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp4icy3l8m.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpcxas_acy.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpksex_6u4.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/20063_S1_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp4icy3l8m.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpcxas_acy.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpksex_6u4.sam']
# --[2019-09-30 16:20:59] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp4icy3l8m.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgad4b51r.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp4icy3l8m.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgad4b51r.fastq.gz']
# --[2019-09-30 16:20:59] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpcxas_acy.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp2z3fx417.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpcxas_acy.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp2z3fx417.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:20:59] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgad4b51r.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp2z3fx417.fastq.gz--
# --[2019-09-30 16:20:59] bin/bbmap/bbduk.sh in=GW9_counts/20063_S1_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpi_el0m2s.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:21:00] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpi_el0m2s.fastq.gz out=GW9_counts/20063_S1_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:21:00] bin/bbmap/kmercountexact.sh in=GW9_counts/20063_S1_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpf6xr_4s8.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/20063_S1_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpf6xr_4s8.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:21:01] bin/bbmap/bbmerge.sh in=GW9_counts/966-61_S61_L001_R1_001.fastq.gz in2=GW9_counts/966-61_S61_L001_R2_001.fastq.gz out=GW9_counts/966-61_S61_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:21:18] bin/bbmap/bbduk.sh in=GW9_counts/966-61_S61_L001.merged.fastq.gz outm=GW9_counts/966-61_S61_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:21:21] bin/bbmap/bbduk.sh in=GW9_counts/966-61_S61_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/966-61_S61_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:21:21] bin/bbmap/bbmap.sh in=GW9_counts/966-61_S61_L001.containing_barcode.fastq.gz outm=GW9_counts/966-61_S61_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:21:28] bin/bbmap/splitsam.sh GW9_counts/966-61_S61_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpb5nc_2th.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdjyamxlp.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuj7ch7nu.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/966-61_S61_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpb5nc_2th.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdjyamxlp.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuj7ch7nu.sam']
# --[2019-09-30 16:21:29] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpb5nc_2th.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp7bc28wra.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpb5nc_2th.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp7bc28wra.fastq.gz']
# --[2019-09-30 16:21:29] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdjyamxlp.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpmnwg7gwq.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdjyamxlp.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpmnwg7gwq.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:21:30] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp7bc28wra.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpmnwg7gwq.fastq.gz--
# --[2019-09-30 16:21:30] bin/bbmap/bbduk.sh in=GW9_counts/966-61_S61_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphhfb83f_.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:21:30] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphhfb83f_.fastq.gz out=GW9_counts/966-61_S61_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:21:31] bin/bbmap/kmercountexact.sh in=GW9_counts/966-61_S61_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tm
L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:23:34] bin/bbmap/bbduk.sh in=GW9_counts/848-04_S4_L001.merged.fastq.gz outm=GW9_counts/848-04_S4_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:23:39] bin/bbmap/bbduk.sh in=GW9_counts/848-04_S4_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/848-04_S4_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:23:40] bin/bbmap/bbmap.sh in=GW9_counts/848-04_S4_L001.containing_barcode.fastq.gz outm=GW9_counts/848-04_S4_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:23:47] bin/bbmap/splitsam.sh GW9_counts/848-04_S4_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq0_blajl.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpiqqs2w9g.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkvnpm4on.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/848-04_S4_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq0_blajl.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpiqqs2w9g.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkvnpm4on.sam']
# --[2019-09-30 16:23:47] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq0_blajl.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdwi9kb3z.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq0_blajl.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdwi9kb3z.fastq.gz']
# --[2019-09-30 16:23:48] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpiqqs2w9g.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvw14i24a.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpiqqs2w9g.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvw14i24a.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:23:48] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdwi9kb3z.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvw14i24a.fastq.gz--
# --[2019-09-30 16:23:48] bin/bbmap/bbduk.sh in=GW9_counts/848-04_S4_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphupv7gyx.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:23:49] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphupv7gyx.fastq.gz out=GW9_counts/848-04_S4_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:23:49] bin/bbmap/kmercountexact.sh in=GW9_counts/848-04_S4_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuse_a42q.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/848-04_S4_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuse_a42q.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:23:50] bin/bbmap/bbmerge.sh in=GW9_counts/1253-18_S16_L001_R1_001.fastq.gz in2=GW9_counts/1253-18_S16_L001_R2_001.fastq.gz out=GW9_counts/1253-18_S16_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:24:02] bin/bbmap/bbduk.sh in=GW9_counts/1253-18_S16_L001.merged.fastq.gz outm=GW9_counts/1253-18_S16_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:03] bin/bbmap/bbduk.sh in=GW9_counts/1253-18_S16_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/1253-18_S16_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:04] bin/bbmap/bbmap.sh in=GW9_counts/1253-18_S16_L001.containing_barcode.fastq.gz outm=GW9_counts/1253-18_S16_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:24:09] bin/bbmap/splitsam.sh GW9_counts/1253-18_S16_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpagzi1z20.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphaccublh.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkvc4f2_a.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/1253-18_S16_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpagzi1z20.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphaccublh.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkvc4f2_a.sam']
# --[2019-09-30 16:24:09] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpagzi1z20.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmplhkplxrs.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpagzi1z20.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmplhkplxrs.fastq.gz']
# --[2019-09-30 16:24:09] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphaccublh.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkujh4qlq.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmphaccublh.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkujh4qlq.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:24:10] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmplhkplxrs.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpkujh4qlq.fastq.gz--
# --[2019-09-30 16:24:10] bin/bbmap/bbduk.sh in=GW9_counts/1253-18_S16_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpk9l7db43.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:10] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpk9l7db43.fastq.gz out=GW9_counts/1253-18_S16_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:24:11] bin/bbmap/kmercountexact.sh in=GW9_counts/1253-18_S16_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpn60e4hsd.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/1253-18_S16_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpn60e4hsd.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:24:11] bin/bbmap/bbmerge.sh in=GW9_counts/966-59_S59_L001_R1_001.fastq.gz in2=GW9_counts/966-59_S59_L001_R2_001.fastq.gz out=GW9_counts/966-59_S59_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:24:27] bin/bbmap/bbduk.sh in=GW9_counts/966-59_S59_L001.merged.fastq.gz outm=GW9_counts/966-59_S59_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:30] bin/bbmap/bbduk.sh in=GW9_counts/966-59_S59_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/966-59_S59_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:30] bin/bbmap/bbmap.sh in=GW9_counts/966-59_S59_L001.containing_barcode.fastq.gz outm=GW9_counts/966-59_S59_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:24:38] bin/bbmap/splitsam.sh GW9_counts/966-59_S59_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpzm9jdnen.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9sfg11i2.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq95kf7yz.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/966-59_S59_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpzm9jdnen.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9sfg11i2.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpq95kf7yz.sam']
# --[2019-09-30 16:24:38] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpzm9jdnen.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgi854bir.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpzm9jdnen.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgi854bir.fastq.gz']
# --[2019-09-30 16:24:39] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9sfg11i2.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp5ojc9khf.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9sfg11i2.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp5ojc9khf.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:24:39] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpgi854bir.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp5ojc9khf.fastq.gz--
# --[2019-09-30 16:24:39] bin/bbmap/bbduk.sh in=GW9_counts/966-59_S59_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpo52zc69q.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:24:40] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpo52zc69q.fastq.gz out=GW9_counts/966-59_S59_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:24:41] bin/bbmap/kmercountexact.sh in=GW9_counts/966-59_S59_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmplg0idylv.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/966-59_S59_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmplg0idylv.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:24:41] bin/bbmap/bbmerge.sh in=GW9_counts/20064_S2_L001_R1_001.fastq.gz in2=GW9_counts/20064_S2_L001_R2_001.fastq.gz out=GW9_counts/20064_S2_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:25:02] bin/bbmap/bbduk.sh in=GW9_counts/20064_S2_L001.merged.fastq.gz outm=GW9_counts/20064_S2_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:05] bin/bbmap/bbduk.sh in=GW9_counts/20064_S2_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/20064_S2_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:05] bin/bbmap/bbmap.sh in=GW9_counts/20064_S2_L001.containing_barcode.fastq.gz outm=GW9_counts/20064_S2_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:25:15] bin/bbmap/splitsam.sh GW9_counts/20064_S2_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjf74x5e5.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdr5f9qir.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpabn7_hpd.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/20064_S2_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjf74x5e5.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdr5f9qir.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpabn7_hpd.sam']
# --[2019-09-30 16:25:15] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjf74x5e5.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjt_lftx7.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjf74x5e5.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjt_lftx7.fastq.gz']
# --[2019-09-30 16:25:15] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdr5f9qir.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuwzeee1i.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpdr5f9qir.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuwzeee1i.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:25:16] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjt_lftx7.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpuwzeee1i.fastq.gz--
# --[2019-09-30 16:25:16] bin/bbmap/bbduk.sh in=GW9_counts/20064_S2_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmps5mjh9qx.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:16] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmps5mjh9qx.fastq.gz out=GW9_counts/20064_S2_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:25:17] bin/bbmap/kmercountexact.sh in=GW9_counts/20064_S2_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpn3s_bphp.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/20064_S2_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpn3s_bphp.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:25:17] bin/bbmap/bbmerge.sh in=GW9_counts/20066_S4_L001_R1_001.fastq.gz in2=GW9_counts/20066_S4_L001_R2_001.fastq.gz out=GW9_counts/20066_S4_L001.merged.fastq.gz qtrim=t ow=t--
# --[2019-09-30 16:25:27] bin/bbmap/bbduk.sh in=GW9_counts/20066_S4_L001.merged.fastq.gz outm=GW9_counts/20066_S4_L001.containing_upstream_flank.fastq.gz literal=TTGCAGCAGCCCAACAGAGG k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:29] bin/bbmap/bbduk.sh in=GW9_counts/20066_S4_L001.containing_upstream_flank.fastq.gz outm=GW9_counts/20066_S4_L001.containing_barcode.fastq.gz literal=AATTGTGGGAAAGAGGGACA k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:30] bin/bbmap/bbmap.sh in=GW9_counts/20066_S4_L001.containing_barcode.fastq.gz outm=GW9_counts/20066_S4_L001.mapped.sam ref=ref/M33262.fasta ow=t--
# --[2019-09-30 16:25:36] bin/bbmap/splitsam.sh GW9_counts/20066_S4_L001.mapped.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjyedv_l5.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp3fizbwws.sam /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmprz9d1wu2.sam--
# ['bin/bbmap/splitsam.sh', 'GW9_counts/20066_S4_L001.mapped.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjyedv_l5.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp3fizbwws.sam', '/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmprz9d1wu2.sam']
# --[2019-09-30 16:25:36] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjyedv_l5.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpxtmhro_1.fastq.gz--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpjyedv_l5.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpxtmhro_1.fastq.gz']
# --[2019-09-30 16:25:36] bin/bbmap/reformat.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp3fizbwws.sam out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvuj5whup.fastq.gz rcomp=t--
# ['bin/bbmap/reformat.sh', 'in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp3fizbwws.sam', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvuj5whup.fastq.gz', 'rcomp=t']
# --[2019-09-30 16:25:37] cat /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpxtmhro_1.fastq.gz /var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmpvuj5whup.fastq.gz--
# --[2019-09-30 16:25:37] bin/bbmap/bbduk.sh in=GW9_counts/20066_S4_L001.oriented.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9z_50a85.fastq.gz literal=TTGCAGCAGCCCAACAGAGG ktrim=l rcomp=f k=20 hdist=1 ow=t--
# --[2019-09-30 16:25:37] bin/bbmap/bbduk.sh in=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp9z_50a85.fastq.gz out=GW9_counts/20066_S4_L001.barcodes.fastq.gz literal=AATTGTGGGAAAGAGGGACA ktrim=r rcomp=f k=20 hdist=1 minlength=27 maxlength=27 ow=t--
# --[2019-09-30 16:25:38] bin/bbmap/kmercountexact.sh in=GW9_counts/20066_S4_L001.barcodes.fastq.gz out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp7r22grld.txt fastadump=f k=27 rcomp=f--
# ['bin/bbmap/kmercountexact.sh', 'in=GW9_counts/20066_S4_L001.barcodes.fastq.gz', 'out=/var/folders/lz/b8xzxdf952bck9bb57k2d4yr0000gq/T/tmp7r22grld.txt', 'fastadump=f', 'k=27', 'rcomp=f']
# --[2019-09-30 16:25:38] bin/bbmap/bbmerge.sh in=GW9_counts/848-06_S6_L001_R1_001.fastq.gz in2=GW9_counts/848-06_S6_L001_R2_001.fastq.gz out=GW9_counts/848-06_S6_L001.merged.fastq.gz qtrim=t ow=t--
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-55603ade7137> in <module>
#      19                  'qtrim=t',
#      20                  'ow=t'],
# ---> 21                  stderr_file = STATS_PATH + '/' + SAMPLE_NAME + '.merging.stats.txt')
#      22
#      23     ## 5. Extracting reads that contain the barcode ##
#
# <ipython-input-7-e97e256c670a> in run_command(cmd_list, stdout_file, stderr_file)
#      79     elif stdout_file is None and stderr_file is not None:
#      80         with open(stderr_file, 'w') as se:
# ---> 81             subprocess.call(cmd_list, stderr = se)
#      82
#      83     # if both stdout and stderr are specified
#
# /anaconda3/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# /anaconda3/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# /anaconda3/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
